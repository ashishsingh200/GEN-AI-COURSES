# %% [markdown]
# ![my image](images/task1.png)

# %% [markdown]
# ## 1.Create a list named products containing atleast 6 product_names(Strings)

# %%
products=['Biscuit','Copy','Pen','Cosmetics','Deodrant','Mobile Phones']
print(products)
print(type(products))
# Out:
# ['Biscuit', 'Copy', 'Pen', 'Cosmetics', 'Deodrant', 'Mobile Phones']
# <class 'list'>

# %% [markdown]
# ## 2.Create a tuple named sample_product that stores(product_name,price_category) for one product.

# %%
sample_product=('Deodrant','Premium')

product_name, price_category=sample_product #Unpacking
print(product_name)
print(price_category)
# Out:
# Deodrant
# Premium

# %% [markdown]
# ## 3.Print 2nd and last product from product list.

# %%
print(f'2nd product from product list is: {products[1]}')
print(f'Last product from product list is: {products[-1]}')
# Out:
# 2nd product from product list is: Copy
# Last product from product list is: Mobile Phones

# %% [markdown]
# ## 4.Append two new Product names to products and then print the new updated list.

# %%
products.append('Shampoo')
products.append('Toothpaste')
print(products)
# Out:
# ['Biscuit', 'Copy', 'Pen', 'Cosmetics', 'Deodrant', 'Mobile Phones', 'Shampoo', 'Toothpaste']

# %% [markdown]
# ## Extra: Convert sample_product into list, change its price and convert it back to a tuple.

# %%
sample_product=list(sample_product) #01. converting to list

sample_product[1]=1299 #02. changing its price
sample_product=tuple(sample_product) #03. converting back to a tuple
type(sample_product)
# Out:
# tuple
