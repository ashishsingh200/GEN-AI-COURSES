# %% [markdown]
# # Encapsulation

# %% [markdown]
# ## Encapsulation is a way of wrapping data(Variables) and methods inside a capsule or a class as asingle unit.
#
# ## It restricts the direct access to some of the objects components which is a means of preventing accidental inference and misuse of the data

# %% [markdown]
# #### Key Concepts of Encapsulation
#
# 1. Public Members
#
# 2. Protected Members
#
# 3. Private Members
#
# 4. Getter and Setter Methods

# %% [markdown]
# # Public

# %%
class Student:
    def __init__(self,name,age):
        self.name=name #public
        self.age=age #public

    def show(self): #public
        print(f"Name: {self.name}, Age: {self.age}")

# %%
s=Student('Ashish',25)
print(s.name)
print(s.age)
s.show()
# Out:
# Ashish
# 25
# Name: Ashish, Age: 25

# %%
s.name='Prince' #can change directly we can modify directly
s.show()
# Out:
# Name: Prince, Age: 25

# %%
dir(Student)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'show']

# %% [markdown]
# ## Private Members --> A Private member is not accessible outside the class and just even in the derived class. In order to have these private access over private members or to bring some modification on these members we use getter and setter method.

# %%
class Avenger:
    def __init__(self,name,phone_number):
        self.name=name
        self.__phone_number=phone_number #making contact details private
    def details(self):
        print(f'My name is {self.name}. I am an Avenger.If you face any problem call me {self.__phone_number}')

# %%
iron_man=Avenger('Tony Stark','8328897003')
iron_man.details()
# Out:
# My name is Tony Stark. I am an Avenger.If you face any problem call me 8328897003

# %%
iron_man.name
# Out:
# 'Tony Stark'

# %%
iron_man.phone_number
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 iron_man.phone_number
#
# AttributeError: 'Avenger' object has no attribute 'phone_number'
