# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # Python Syntax Rules

# %% [markdown]
# ## 1. Python is case sensitive

# %%
name='ashish'
Name='ashish'
name==Name
# Out:
# True

# %%
name='ashish'
Name='Ashish'
name==Name
# Out:
# False

# %% [markdown]
# ## Indentation in python

# %%
age=int(input("Enter Your Age:"))
if age > 18:
    print("Eligible for Driving")
# Out:
# Eligible for Driving

# %%
age=int(input("Enter Your Age:"))
if age > 18:
print("Eligible for Driving")
# Out:
#   Cell In[5], line 3
#     print("Eligible for Driving")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %% [markdown]
# ### Backslash ----> we can use backslash for continuing in the next line

# %%
1+2+3+4+5\
    +6+7
# Out:
# 28
