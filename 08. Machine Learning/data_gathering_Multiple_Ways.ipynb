# %% [markdown]
# #  1. CSV files
#
# ### can be downloaded from kaggle
#
# # 2. Database
#
# # 3. Json
#
# # 4. Excel
#
# # 5. API (Application Programming Interface)
#
# # 6. Web Scrapping

# %%
import pandas as pd

# %%
# Data Gathering from read_csv

dg1=pd.read_csv('data/Student Depression Dataset.csv')

# %%
dg1.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#       Sleep Duration Dietary Habits   Degree  \
# 0          5-6 hours        Healthy  B.Pharm
# 1          5-6 hours       Moderate      BSc
# 2  Less than 5 hours        Healthy       BA
# ...

# %%
# Data Gathering from excel file
dg2=pd.read_excel('data/01 Retail Inventory.xlsx')

# %%
dg2.head()
# Out:
#   Product ID     Product Name           Category          Supplier Name  \
# 0   PRD-1001     Wine Glasses     Home & Kitchen        Heritage Brands
# 1   PRD-1002         Eye Mask             Beauty        Coastal Trading
# 2   PRD-1003  Resistance Band  Sports & Outdoors  National Supply Group
# 3   PRD-1004    Action Figure       Toys & Games      Pacific Wholesale
# 4   PRD-1005     Serving Tray     Home & Kitchen        Coastal Trading
#
#    Unit Cost  Retail Price  Opening Stock  Units Sold  Closing Stock  \
# 0      23.78         38.89            135         118             17
# 1      15.67         24.53             86          10             76
# 2       5.59         11.88            319         195            124
# 3       9.72         18.01            173         140             33
# 4       8.22         13.90             32           8             24
#
#    Reorder Point Stock Status
# 0             30    Low Stock
# 1              9     In Stock
# ...

# %%
# reading tsv file
#tsv stands for ---> Tab Space Value

# %%
dg3=pd.read_csv('data/demo_mlexpec.tsv',sep='\t')

# %%
dg3
# Out:
#       unit,sex,age,geo\time 2021   2020   2019   2018   2017    2016   2015   \
# 0                YR,F,Y1,AL    :   79.4   80.4   80.2   79.7    79.8   79.2
# 1                YR,F,Y1,AM    :      :   79.1   79.2   78.5    78.0   77.9
# 2                YR,F,Y1,AT    :   82.9   83.5   83.3   83.2    83.4   83.0
# 3                YR,F,Y1,AZ    :      :   78.6   78.1   77.7       :   77.5
# 4                YR,F,Y1,BE    :   82.3   83.6   83.2   83.2    83.2   82.6
# ...                     ...   ...    ...    ...    ...    ...     ...    ...
# 14443         YR,T,Y_LT1,SM    :      :      :      :      :       :      :
# 14444         YR,T,Y_LT1,TR    :      :   79.1   78.9   78.5    78.1   78.2
# 14445         YR,T,Y_LT1,UA    :      :   73.4   73.2   73.3    72.9   72.5
# 14446         YR,T,Y_LT1,UK    :      :      :   81.3   81.3    81.2   81.0
# 14447         YR,T,Y_LT1,XK    :      :      :      :      :   78.6 p     :
#
# ...

# %% [markdown]
# #### names ----> names is going to take a list of names that we can provide to our column names only

# %%
data_path='/Users/ashishsingh/Desktop/GEN AI/08. Machine Learning/data/Student Depression Dataset.csv'
dg4=pd.read_csv(data_path,names=[ 'student_id',	'Gender',	'Age',	'City',	'Profession',	'Academic Pressure',	'Work Pressure',	'CGPA',	'Study Satisfaction',	'Job Satisfaction', 'Sleep Duration',	'Dietary Habits',	'Degree',	'suicidal thoughts', 	'Work/Study Hours',	'Financial Stress',	'Mental Illness',	'Depression'])

# %%
dg4.head()
# Out:
#   student_id  Gender   Age           City  Profession  Academic Pressure  \
# 0         id  Gender   Age           City  Profession  Academic Pressure
# 1          2    Male  33.0  Visakhapatnam     Student                5.0
# 2          8  Female  24.0      Bangalore     Student                2.0
# 3         26    Male  31.0       Srinagar     Student                3.0
# 4         30  Female  28.0       Varanasi     Student                3.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0  Work Pressure  CGPA  Study Satisfaction  Job Satisfaction
# 1            0.0  8.97                 2.0               0.0
# 2            0.0   5.9                 5.0               0.0
# 3            0.0  7.03                 5.0               0.0
# 4            0.0  5.59                 2.0               0.0
#
#       Sleep Duration  Dietary Habits   Degree  \
# 0     Sleep Duration  Dietary Habits   Degree
# 1          5-6 hours         Healthy  B.Pharm
# ...

# %%
dg5=pd.read_csv(data_path)

# %%
dg5.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  str
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  str
#  4   Profession                             27901 non-null  str
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
#  10  Sleep Duration                         27901 non-null  str
# ...

# %%
dg5['Financial Stress'].unique()
# Out:
# array([ 1.,  2.,  5.,  3.,  4., nan])

# %%
median_value=dg5['Financial Stress'].median()
dg5['Financial Stress'].fillna(median_value)
# Out:
# 0        1.0
# 1        2.0
# 2        1.0
# 3        5.0
# 4        1.0
#         ...
# 27896    1.0
# 27897    3.0
# 27898    2.0
# 27899    5.0
# 27900    3.0
# Name: Financial Stress, Length: 27901, dtype: float64

# %%
dg5.shape
# Out:
# (27901, 18)

# %%
dfs=pd.read_csv(data_path,chunksize=5000)

# %%
for chunk in dfs:
    print(chunk.shape)
# Out:
# (5000, 18)
# (5000, 18)
# (5000, 18)
# (5000, 18)
# (5000, 18)
# (2901, 18)

# %% [markdown]
# # Data Gathering in JSON, SQL & Role in Agentic AI and GEN AI Development

# %% [markdown]
# ### 1. JSON

# %%
# DAtA PATH
CSV_DATA='data/Student Depression Dataset.csv'
JSON_DATA='data/iris.json'
TSV_DATA='data/demo_mlexpec.tsv'
EXCEL_DATA='data/01 Retail Inventory.xlsx'

# %%
json_data=pd.read_json(JSON_DATA)

# %%
json_data.head()
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa
# 2          4.7         3.2          1.3         0.2  setosa
# 3          4.6         3.1          1.5         0.2  setosa
# 4          5.0         3.6          1.4         0.2  setosa

# %% [markdown]
# ### 2. SQL DATABASE

# %%
pip install mysql.connector
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector

# %%
import mysql.connector
print(mysql.connector.__version__)
# Out:
# 9.7.0

# %%
pip install --upgrade mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
host='localhost'
useer='root'
password='*******'
db='UBER_DATASET'
data=mysql.connector.connect(
    host=host,
    user=useer,
    password=password,
    database=db)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~/Desktop/GEN AI/.venv/lib/python3.12/site-packages/mysql/connector/connection_cext.py:354, in CMySQLConnection._open_connection(self)
#     353 try:
# --> 354     self._cmysql.connect(**cnx_kwargs)
#     355     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Access denied for user 'root'@'localhost' (using password: YES)
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[25], line 5
#       1 host='localhost'
#       2 useer='root'
#       3 password='*******'
#       4 db='UBER_DATASET'
# ----> 5 data=mysql.connector.connect(
#       6     host=host,
#       7     user=useer,
#       8     password=password,
#
# ...

# %%
data

# %%
df = pd.read_sql_query('Select * from drivers',data)
# Out:
# /var/folders/c1/6c8s3wn93nd1yg_s50mdh4nc0000gn/T/ipykernel_4035/3727180721.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query('Select * from drivers',data)

# %%
df.head()
# Out:
#    driver_id  user_id vehicle_make vehicle_model  vehicle_year license_plate  \
# 0          1     1781          Kia          Soul          2015      ZVJ-2140
# 1          2      408      Hyundai        Tucson          2016      WLW-3906
# 2          3      693      Hyundai        Sonata          2014      WEA-5140
# 3          4      187       Nissan         Rogue          2021      KDE-9978
# 4          5     1499         Ford        Fusion          2019      EKJ-8600
#
#    rating   join_date  is_active
# 0    4.10  2019-12-22          1
# 1    4.21  2020-12-14          1
# 2    3.81  2023-07-25          1
# 3    4.82  2020-01-11          1
# 4    3.30  2023-07-15          0

# %%
df.shape
# Out:
# (400, 9)

# %%
pd.read_sql_query("select * from payments",data)
# Out:
# /var/folders/c1/6c8s3wn93nd1yg_s50mdh4nc0000gn/T/ipykernel_4035/1866268105.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("select * from payments",data)
#        payment_id  trip_id  amount  method   status             paid_at
# 0               1        1   68.55  wallet  success 2024-06-24 14:24:15
# 1               2        3    6.36  wallet  success 2023-08-17 09:36:16
# 2               3        4   21.98    cash  success 2022-11-21 10:17:36
# 3               4        5   56.99  wallet  success 2022-01-15 14:57:02
# 4               5        6   55.56    cash  success 2022-05-05 08:34:02
# ...           ...      ...     ...     ...      ...                 ...
# 16822       16823    19995   23.30    card  success 2023-02-24 06:37:30
# ...

# %%
pd.read_sql_query(
    "select * from payments where amount > 100"
    ,data
    )
# Out:
# /var/folders/c1/6c8s3wn93nd1yg_s50mdh4nc0000gn/T/ipykernel_4035/2996508660.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query(
#      payment_id  trip_id  amount  method   status             paid_at
# 0            35       41  125.25    cash  success 2023-12-15 20:14:10
# 1            76       86  118.25    cash  success 2022-08-12 01:36:05
# 2           103      120  102.71  wallet  success 2024-06-28 20:30:13
# 3           104      121  121.07    cash  success 2024-01-13 00:47:42
# 4           137      158  119.41    card  success 2024-03-08 09:02:12
# ..          ...      ...     ...     ...      ...                 ...
# 564       16639    19774  102.96  wallet  success 2022-09-19 18:01:01
# 565       16678    19820  113.21    card  success 2024-01-02 19:17:44
# ...

# %%
pd.read_sql_query(
    "select * from payments where method='cash'"
    ,data
    )
# Out:
# /var/folders/c1/6c8s3wn93nd1yg_s50mdh4nc0000gn/T/ipykernel_4035/2272188790.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query(
#       payment_id  trip_id  amount method   status             paid_at
# 0              3        4   21.98   cash  success 2022-11-21 10:17:36
# 1              5        6   55.56   cash  success 2022-05-05 08:34:02
# 2              6        8    8.70   cash  success 2023-04-17 10:28:36
# 3              7        9   24.05   cash  success 2022-09-09 23:27:45
# 4              8       10   38.96   cash  success 2022-06-13 10:41:38
# ...          ...      ...     ...    ...      ...                 ...
# 5501       16805    19976   35.14   cash  success 2023-06-12 20:16:22
# 5502       16811    19982   39.87   cash  success 2022-05-06 05:39:36
# ...

# %% [markdown]
# ### 3. API

# %% [markdown]
# https://api.themoviedb.org/3/genre/movie/list?api_key=107df16507f64dac79467a3685d428ad&language=en

# %%
url='https://api.themoviedb.org/3/genre/movie/list?language=en'
api_key='107df16507f64dac79467a3685d428ad'

# %%
import requests

# %%
import requests

url = "https://api.themoviedb.org/3/genre/movie/list?api_key=107df16507f64dac79467a3685d428ad&language=en"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIxMDdkZjE2NTA3ZjY0ZGFjNzk0NjdhMzY4NWQ0MjhhZCIsIm5iZiI6MTc1ODgwMzE0Mi4zOTIsInN1YiI6IjY4ZDUzNGM2ZmU3ZjYxMWQwZDE5ZGNhMCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.XvYrspn1p-9vslUcIZN3DY3FT2uu3m8W1tL9N6inFqQ"
}

response = requests.get(url, headers=headers)

print(response)
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'genres': [{'id': 28, 'name': 'Action'},
#   {'id': 12, 'name': 'Adventure'},
#   {'id': 16, 'name': 'Animation'},
#   {'id': 35, 'name': 'Comedy'},
#   {'id': 80, 'name': 'Crime'},
#   {'id': 99, 'name': 'Documentary'},
#   {'id': 18, 'name': 'Drama'},
#   {'id': 10751, 'name': 'Family'},
#   {'id': 14, 'name': 'Fantasy'},
#   {'id': 36, 'name': 'History'},
#   {'id': 27, 'name': 'Horror'},
#   {'id': 10402, 'name': 'Music'},
#   {'id': 9648, 'name': 'Mystery'},
#   {'id': 10749, 'name': 'Romance'},
#   {'id': 878, 'name': 'Science Fiction'},
#   {'id': 10770, 'name': 'TV Movie'},
#   {'id': 53, 'name': 'Thriller'},
#   {'id': 10752, 'name': 'War'},
#   {'id': 37, 'name': 'Western'}]}

# %%
mdb=pd.DataFrame(response.json())

# %%
mdb
# Out:
#                                     genres
# 0             {'id': 28, 'name': 'Action'}
# 1          {'id': 12, 'name': 'Adventure'}
# 2          {'id': 16, 'name': 'Animation'}
# 3             {'id': 35, 'name': 'Comedy'}
# 4              {'id': 80, 'name': 'Crime'}
# 5        {'id': 99, 'name': 'Documentary'}
# 6              {'id': 18, 'name': 'Drama'}
# 7          {'id': 10751, 'name': 'Family'}
# 8            {'id': 14, 'name': 'Fantasy'}
# 9            {'id': 36, 'name': 'History'}
# 10            {'id': 27, 'name': 'Horror'}
# 11          {'id': 10402, 'name': 'Music'}
# 12         {'id': 9648, 'name': 'Mystery'}
# 13        {'id': 10749, 'name': 'Romance'}
# 14  {'id': 878, 'name': 'Science Fiction'}
# 15       {'id': 10770, 'name': 'TV Movie'}
# 16          {'id': 53, 'name': 'Thriller'}
# 17            {'id': 10752, 'name': 'War'}
# 18           {'id': 37, 'name': 'Western'}

# %%
import requests

url = "https://api.themoviedb.org/3/movie/changes?api_key=107df16507f64dac79467a3685d428ad&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIxMDdkZjE2NTA3ZjY0ZGFjNzk0NjdhMzY4NWQ0MjhhZCIsIm5iZiI6MTc1ODgwMzE0Mi4zOTIsInN1YiI6IjY4ZDUzNGM2ZmU3ZjYxMWQwZDE5ZGNhMCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.XvYrspn1p-9vslUcIZN3DY3FT2uu3m8W1tL9N6inFqQ"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"results":[{"id":4232,"adult":false,"softcore":false},{"id":128128,"adult":false,"softcore":false},{"id":1449851,"adult":true,"softcore":false},{"id":1865,"adult":false,"softcore":false},{"id":1575876,"adult":false,"softcore":false},{"id":1720236,"adult":false,"softcore":false},{"id":1728263,"adult":false,"softcore":false},{"id":1550164,"adult":false,"softcore":false},{"id":1688641,"adult":false,"softcore":false},{"id":1698041,"adult":false,"softcore":false},{"id":1701009,"adult":false,"softcore":false},{"id":1707841,"adult":false,"softcore":false},{"id":1712734,"adult":false,"softcore":false},{"id":1714990,"adult":false,"softcore":false},{"id":1715467,"adult":false,"softcore":false},{"id":1720899,"adult":false,"softcore":false},{"id":1720907,"adult":false,"softcore":false},{"id":1723414,"adult":false,"softcore":false},{"id":1724844,"adult":false,"softcore":false},{"id":1725160,"adult":false,"softcore":false},{"id":1725314,"adult":false,"softcore":false},{"id":1726851,"adult":false,
# ...

# %%
mdb=pd.DataFrame(response.json()['results'])
mdb
# Out:
#          id  adult softcore
# 0      4232  False    False
# 1    128128  False    False
# 2   1449851   True    False
# 3      1865  False    False
# 4   1575876  False    False
# ..      ...    ...      ...
# 95  1189735  False    False
# 96  1728418  False    False
# 97  1728419   None     None
# 98   324857  False    False
# 99  1621607  False    False
#
# [100 rows x 3 columns]

# %%
import requests

url = "https://api.themoviedb.org/3/account/22336859"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIxMDdkZjE2NTA3ZjY0ZGFjNzk0NjdhMzY4NWQ0MjhhZCIsIm5iZiI6MTc1ODgwMzE0Mi4zOTIsInN1YiI6IjY4ZDUzNGM2ZmU3ZjYxMWQwZDE5ZGNhMCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.XvYrspn1p-9vslUcIZN3DY3FT2uu3m8W1tL9N6inFqQ"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"avatar":{"gravatar":{"hash":"210e81663d9e765704baa42fc5de3cad"},"tmdb":{"avatar_path":null}},"id":22336859,"iso_639_1":"en","iso_3166_1":"IN","name":"","include_adult":false,"username":"ashish_zoro"}

# %%
response.json()
# Out:
# {'avatar': {'gravatar': {'hash': '210e81663d9e765704baa42fc5de3cad'},
#   'tmdb': {'avatar_path': None}},
#  'id': 22336859,
#  'iso_639_1': 'en',
#  'iso_3166_1': 'IN',
#  'name': '',
#  'include_adult': False,
#  'username': 'ashish_zoro'}

# %%
pd.DataFrame(response.json())
# Out:
#                                                 avatar        id iso_639_1  \
# gravatar  {'hash': '210e81663d9e765704baa42fc5de3cad'}  22336859        en
# tmdb                             {'avatar_path': None}  22336859        en
#
#          iso_3166_1 name  include_adult     username
# gravatar         IN               False  ashish_zoro
# tmdb             IN               False  ashish_zoro

# %%
import requests

url = "https://api.themoviedb.org/3/movie/changes?page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIxMDdkZjE2NTA3ZjY0ZGFjNzk0NjdhMzY4NWQ0MjhhZCIsIm5iZiI6MTc1ODgwMzE0Mi4zOTIsInN1YiI6IjY4ZDUzNGM2ZmU3ZjYxMWQwZDE5ZGNhMCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.XvYrspn1p-9vslUcIZN3DY3FT2uu3m8W1tL9N6inFqQ"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"results":[{"id":4232,"adult":false,"softcore":false},{"id":128128,"adult":false,"softcore":false},{"id":1449851,"adult":true,"softcore":false},{"id":1865,"adult":false,"softcore":false},{"id":1575876,"adult":false,"softcore":false},{"id":1720236,"adult":false,"softcore":false},{"id":1728263,"adult":false,"softcore":false},{"id":1550164,"adult":false,"softcore":false},{"id":1688641,"adult":false,"softcore":false},{"id":1698041,"adult":false,"softcore":false},{"id":1701009,"adult":false,"softcore":false},{"id":1707841,"adult":false,"softcore":false},{"id":1712734,"adult":false,"softcore":false},{"id":1714990,"adult":false,"softcore":false},{"id":1715467,"adult":false,"softcore":false},{"id":1720899,"adult":false,"softcore":false},{"id":1720907,"adult":false,"softcore":false},{"id":1723414,"adult":false,"softcore":false},{"id":1724844,"adult":false,"softcore":false},{"id":1725160,"adult":false,"softcore":false},{"id":1725314,"adult":false,"softcore":false},{"id":1726851,"adult":false,
# ...

# %%
pd.DataFrame(response.json()['results'])
# Out:
#          id  adult softcore
# 0      4232  False    False
# 1    128128  False    False
# 2   1449851   True    False
# 3      1865  False    False
# 4   1575876  False    False
# ..      ...    ...      ...
# 95  1189735  False    False
# 96  1728418  False    False
# 97  1728419   None     None
# 98   324857  False    False
# 99  1621607  False    False
#
# [100 rows x 3 columns]

# %%
import requests

url = "https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page=1&sort_by=popularity.desc"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIxMDdkZjE2NTA3ZjY0ZGFjNzk0NjdhMzY4NWQ0MjhhZCIsIm5iZiI6MTc1ODgwMzE0Mi4zOTIsInN1YiI6IjY4ZDUzNGM2ZmU3ZjYxMWQwZDE5ZGNhMCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.XvYrspn1p-9vslUcIZN3DY3FT2uu3m8W1tL9N6inFqQ"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"page":1,"results":[{"adult":false,"backdrop_path":"/rZfmzpixLKLR3Hg2u0WgC7XLFl8.jpg","genre_ids":[27,53],"id":1339713,"title":"Obsession","original_language":"en","original_title":"Obsession","overview":"After breaking the mysterious \"One Wish Willow\" to win his crush's heart, a hopeless romantic finds himself getting exactly what he asked for but soon discovers that some desires come at a dark, sinister price.","popularity":722.1192,"poster_path":"/bRwnj8WEKBCvmfeUNOukJPwB43K.jpg","release_date":"2026-05-13","softcore":false,"video":false,"vote_average":8.271,"vote_count":2445},{"adult":false,"backdrop_path":"/qjTqY5coNiz6sVtPng40IzltsoN.jpg","genre_ids":[16,10751,35,12],"id":1084244,"title":"Toy Story 5","original_language":"en","original_title":"Toy Story 5","overview":"When Bonnie receives a Lilypad tablet as a gift and becomes obsessed, Buzz, Woody, Jessie and the rest of the gang's jobs become exponentially harder when they have to go head to head with the all-new threat to
# ...

# %%
pd.DataFrame(response.json()['results'])
# Out:
#     adult                     backdrop_path                genre_ids       id  \
# 0   False  /rZfmzpixLKLR3Hg2u0WgC7XLFl8.jpg                 [27, 53]  1339713
# 1   False  /qjTqY5coNiz6sVtPng40IzltsoN.jpg      [16, 10751, 35, 12]  1084244
# 2   False  /s6ly8laenkHWlIBRkLSfIuEMLC6.jpg                [878, 53]  1275779
# 3   False  /mCpwRayjXMFzKHbjbzc5JRKfq1O.jpg          [27, 9648, 878]  1083381
# 4   False  /xWBiXclrRmTggQHMRsIn84YHavs.jpg                     [35]  1273221
# 5   False  /Af907x5h9W1wVis8XrSd7ynTWuy.jpg                 [35, 18]  1314481
# 6   False  /1AVF2fAevpfi2HP6AEpptG1kg8R.jpg             [28, 80, 53]  1280738
# 7   False  /qJ2KSHJhlFvASBMLbGuP7OFMaFg.jpg             [53, 28, 80]  1413976
# 8   False  /szKv713FcUXx6hcfdY369vtkmzr.jpg                 [27, 53]  1127384
# 9   False  /1x9e0qWonw634NhIsRdvnneeqvN.jpg                  [10749]  1523145
# 10  False  /3pDfu71mrzSuFYyIfnKEjt8z4BC.jpg                 [27, 53]  1368314
# ...

# %%
import requests

url = "https://api.themoviedb.org/3/trending/movie/day?api_key=107df16507f64dac79467a3685d428ad&language=en-US"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIxMDdkZjE2NTA3ZjY0ZGFjNzk0NjdhMzY4NWQ0MjhhZCIsIm5iZiI6MTc1ODgwMzE0Mi4zOTIsInN1YiI6IjY4ZDUzNGM2ZmU3ZjYxMWQwZDE5ZGNhMCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.XvYrspn1p-9vslUcIZN3DY3FT2uu3m8W1tL9N6inFqQ"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"page":1,"results":[{"adult":false,"backdrop_path":"/rZfmzpixLKLR3Hg2u0WgC7XLFl8.jpg","id":1339713,"title":"Obsession","original_title":"Obsession","overview":"After breaking the mysterious \"One Wish Willow\" to win his crush's heart, a hopeless romantic finds himself getting exactly what he asked for but soon discovers that some desires come at a dark, sinister price.","poster_path":"/bRwnj8WEKBCvmfeUNOukJPwB43K.jpg","media_type":"movie","original_language":"en","genre_ids":[27,53],"popularity":722.1192,"release_date":"2026-05-13","softcore":false,"video":false,"vote_average":8.273,"vote_count":2453},{"adult":false,"backdrop_path":"/1AVF2fAevpfi2HP6AEpptG1kg8R.jpg","id":1280738,"title":"The Furious","original_title":"火遮眼","overview":"After Wang Wei's daughter is kidnapped by a criminal network and he receives no help from the corrupt police, Wei sets out to find her himself. His only ally is Navin, a relentless journalist whose wife has mysteriously disappeared. Fueled by a furiou
# ...

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/rZfmzpixLKLR3Hg2u0WgC7XLFl8.jpg',
#    'id': 1339713,
#    'title': 'Obsession',
#    'original_title': 'Obsession',
#    'overview': 'After breaking the mysterious "One Wish Willow" to win his crush\'s heart, a hopeless romantic finds himself getting exactly what he asked for but soon discovers that some desires come at a dark, sinister price.',
#    'poster_path': '/bRwnj8WEKBCvmfeUNOukJPwB43K.jpg',
#    'media_type': 'movie',
#    'original_language': 'en',
#    'genre_ids': [27, 53],
#    'popularity': 722.1192,
#    'release_date': '2026-05-13',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.273,
#    'vote_count': 2453},
#   {'adult': False,
#    'backdrop_path': '/1AVF2fAevpfi2HP6AEpptG1kg8R.jpg',
#    'id': 1280738,
#    'title': 'The Furious',
#    'original_title': '火遮眼',
# ...

# %%
tr_mdb=pd.DataFrame(response.json()['results'])

# %%
tr_mdb
# Out:
#     adult                     backdrop_path       id  \
# 0   False  /rZfmzpixLKLR3Hg2u0WgC7XLFl8.jpg  1339713
# 1   False  /1AVF2fAevpfi2HP6AEpptG1kg8R.jpg  1280738
# 2   False  /c6BPbkO5Npt1OdwttAxCFo06wtH.jpg  1108427
# 3   False  /A5Tz6ogGt4VV8NESG9oWVct5bo1.jpg  1212763
# 4   False  /m3Pom6pbD51bBv3syz8NMHda3fz.jpg  1368337
# 5   False  /mCpwRayjXMFzKHbjbzc5JRKfq1O.jpg  1083381
# 6   False  /6tByIjKn3VLEVHhfpiNNWrnSIOM.jpg  1710008
# 7   False  /3pDfu71mrzSuFYyIfnKEjt8z4BC.jpg  1368314
# 8   False  /qjTqY5coNiz6sVtPng40IzltsoN.jpg  1084244
# 9   False   /i5E9H7Ik0u61ylDDTbmUpTL3Yw.jpg  1170608
# 10  False  /vjMvFSmGUxEtqVdaZgvFee9XkZl.jpg   969681
# 11  False  /xMoXsOgF0hBP7iVj7ZPIrFtTeL3.jpg  1315772
# 12  False  /8Tfys3mDZVp4tNoH2ktm06a0Tau.jpg   687163
# 13  False  /kLA1GqiOEyVgXxgNqLoCr7bYcqu.jpg   950028
# 14  False  /t6O6XWelu27BD0OmIDCCufZZT6d.jpg  1301421
# 15  False  /ufSwlnECLoUbBjPrFqEQcWBzHwc.jpg   936075
# 16  False  /Af907x5h9W1wVis8XrSd7ynTWuy.jpg  1314481
# ...

# %%
tr_mdb.to_csv('Top_Rated_Movies_2026.csv',index=False)

# %%
import requests

url = "https://api.themoviedb.org/3/trending/all/day?language=en-US"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIxMDdkZjE2NTA3ZjY0ZGFjNzk0NjdhMzY4NWQ0MjhhZCIsIm5iZiI6MTc1ODgwMzE0Mi4zOTIsInN1YiI6IjY4ZDUzNGM2ZmU3ZjYxMWQwZDE5ZGNhMCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.XvYrspn1p-9vslUcIZN3DY3FT2uu3m8W1tL9N6inFqQ"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"page":1,"results":[{"adult":false,"backdrop_path":"/fBieUo3SdItUrXZE16YxbpjwXIe.jpg","id":283304,"name":"Little House on the Prairie","original_name":"Little House on the Prairie","overview":"The close-knit Ingalls family builds a new life on the Western frontier, where the joys of nature and the struggle for survival are deeply intertwined.","poster_path":"/oWUGSadxC9vQPOCeHDDVfDezmQC.jpg","media_type":"tv","original_language":"en","genre_ids":[18,37,10751],"popularity":41.8913,"first_air_date":"2026-07-09","softcore":false,"vote_average":5.833,"vote_count":6,"origin_country":["US"]},{"adult":false,"backdrop_path":"/A5Tz6ogGt4VV8NESG9oWVct5bo1.jpg","id":1212763,"title":"Evil Dead Burn","original_title":"Evil Dead Burn","overview":"After the loss of her husband, a woman seeks solace with her in-laws. As one by one they transform into deadites, she comes to discover that the vows she took in life - survive even in death.","poster_path":"/ztadKzIIR0ERYqpHteaPFtk7inP.jpg","media_type"
# ...

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/fBieUo3SdItUrXZE16YxbpjwXIe.jpg',
#    'id': 283304,
#    'name': 'Little House on the Prairie',
#    'original_name': 'Little House on the Prairie',
#    'overview': 'The close-knit Ingalls family builds a new life on the Western frontier, where the joys of nature and the struggle for survival are deeply intertwined.',
#    'poster_path': '/oWUGSadxC9vQPOCeHDDVfDezmQC.jpg',
#    'media_type': 'tv',
#    'original_language': 'en',
#    'genre_ids': [18, 37, 10751],
#    'popularity': 41.8913,
#    'first_air_date': '2026-07-09',
#    'softcore': False,
#    'vote_average': 5.833,
#    'vote_count': 6,
#    'origin_country': ['US']},
#   {'adult': False,
#    'backdrop_path': '/A5Tz6ogGt4VV8NESG9oWVct5bo1.jpg',
#    'id': 1212763,
#    'title': 'Evil Dead Burn',
#    'original_title': 'Evil Dead Burn',
# ...

# %%
pd.DataFrame(response.json()['results'])
# Out:
#     adult                     backdrop_path       id  \
# 0   False  /fBieUo3SdItUrXZE16YxbpjwXIe.jpg   283304
# 1   False  /A5Tz6ogGt4VV8NESG9oWVct5bo1.jpg  1212763
# 2   False  /rZfmzpixLKLR3Hg2u0WgC7XLFl8.jpg  1339713
# 3   False  /1AVF2fAevpfi2HP6AEpptG1kg8R.jpg  1280738
# 4   False  /m3Pom6pbD51bBv3syz8NMHda3fz.jpg  1368337
# 5   False  /mCpwRayjXMFzKHbjbzc5JRKfq1O.jpg  1083381
# 6   False  /c6BPbkO5Npt1OdwttAxCFo06wtH.jpg  1108427
# 7   False  /wK1SL5EUJ6Bq2UhDCRtT1FA1HdN.jpg   297826
# 8   False  /3pDfu71mrzSuFYyIfnKEjt8z4BC.jpg  1368314
# 9   False   /i5E9H7Ik0u61ylDDTbmUpTL3Yw.jpg  1170608
# 10  False  /feISh3qoREwIPWbSaLqqumbmh7m.jpg   322055
# 11  False  /6tByIjKn3VLEVHhfpiNNWrnSIOM.jpg  1710008
# 12  False  /xMoXsOgF0hBP7iVj7ZPIrFtTeL3.jpg  1315772
# 13  False  /xLdw1xdHocKYFFvx7w41NchXMfJ.jpg   124364
# 14  False  /qjTqY5coNiz6sVtPng40IzltsoN.jpg  1084244
# 15  False  /jIyEmnBrZtl6SEWyBoMO2hZnzMa.jpg   138502
# 16  False  /kLA1GqiOEyVgXxgNqLoCr7bYcqu.jpg   950028
# ...

# %%
import http.client
import json

conn = http.client.HTTPSConnection("imdb-top-100-movies.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "4208a964f5mshb78c8bc390f8defp13cb64jsn57d0b96d25f4",
    'x-rapidapi-host': "imdb-top-100-movies.p.rapidapi.com",
    'Content-Type': "application/json"
}

conn.request("GET", "/", headers=headers)

res = conn.getresponse()
data = res.read()

json_strings=data.decode("utf-8")

movie_list=json.loads(json_strings)

df = pd.DataFrame(movie_list)
df
# Out:
#     rank                     title  \
# 0      1  The Shawshank Redemption
# 1      2             The Godfather
# 2      3           The Dark Knight
# 3      4     The Godfather Part II
# 4      5              12 Angry Men
# ..   ...                       ...
# 95    96            Reservoir Dogs
# 96    97                     Ikiru
# 97    98        Lawrence of Arabia
# 98    99              Citizen Kane
# 99   100                         M
#
#                                           description  \
# 0   Two imprisoned men bond over a number of years...
# 1   The aging patriarch of an organized crime dyna...
# 2   When the menace known as the Joker wreaks havo...
# 3   The early life and career of Vito Corleone in ...
# 4   The jury in a New York City murder trial is fr...
# ..                                                ...
# 95  When a simple jewelry heist goes horribly wron...
# 96  A bureaucrat tries to find meaning in his life...
# ...

# %%
df.to_csv('mov_list.csv',index=False)
