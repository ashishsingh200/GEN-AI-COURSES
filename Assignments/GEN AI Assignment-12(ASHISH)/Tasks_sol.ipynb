# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ![Task 1](images/task1.png)

# %%
tips=sns.load_dataset('tips')

# %%
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(data=tips,x='day',y='total_bill',hue='smoker',kind='line',style='time')
plt.show()

# %%
sns.relplot(data=tips,x='day',y='total_bill',hue='smoker',kind='scatter')
plt.show()

# %% [markdown]
# ![Task 2](images/task2.png)

# %%
iris=sns.load_dataset('flights')

# %%
iris.head(5)
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
sns.lineplot(data=iris,x='month',y='passengers',hue='year')
# Out:
# <Axes: xlabel='month', ylabel='passengers'>

# %%
sns.scatterplot(data=iris,x='month',y='passengers',hue='year')
# Out:
# <Axes: xlabel='month', ylabel='passengers'>

# %%
sns.relplot(data=iris,x='month',y='passengers',col='year',col_wrap=2)

# %% [markdown]
# ![Task 3](images/task3.png)

# %%
data=sns.load_dataset('titanic')

# %%
data.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
data.shape
# Out:
# (891, 15)

# %%
data['sex'].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
data['class'].value_counts()
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %%
sns.histplot(data=data,x='fare',hue='sex')
plt.show()

# %%
sns.kdeplot(data=data,x='age')
plt.show()

# %%
sns.histplot(data=data,x='age',hue='sex',kde=True)
plt.show()

# %%
sns.rugplot(data=data,x='class',y='age',hue='sex')
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %% [markdown]
# ![Task 4](images/task4.png)

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.histplot(data=data,x='pclass',y='fare',hue='embarked')
# Out:
# <Axes: xlabel='pclass', ylabel='fare'>

# %%
sns.kdeplot(data=data,x='pclass',y='fare',hue='embarked')
# Out:
# <Axes: xlabel='pclass', ylabel='fare'>

# %% [markdown]
# ![Task 5](images/task5.png)

# %%
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
pivot_data=tips.pivot_table(index='tip',columns='smoker',values='total_bill')

# %%
sns.heatmap(pivot_data)
# Out:
# <Axes: xlabel='smoker', ylabel='tip'>

# %%
sns.pairplot(data=pivot_data)

# %% [markdown]
# ![Task 6](images/task6.png)

# %%
iris.head(5)
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
sns.barplot(data=iris,x='month',y='passengers')
# Out:
# <Axes: xlabel='month', ylabel='passengers'>

# %%
sns.boxplot(data=iris,x='month',y='passengers')
# Out:
# <Axes: xlabel='month', ylabel='passengers'>

# %%
sns.violinplot(data=iris,x='month',y='passengers')
# Out:
# <Axes: xlabel='month', ylabel='passengers'>

# %%
sns.countplot(data=iris,x='year')
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %% [markdown]
# ![Task 7](images/task7.png)

# %%
iris=sns.load_dataset('iris')

# %%
iris.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.regplot(data=iris,x='sepal_length',y='sepal_width')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.lmplot(data=iris,x='sepal_length',y='sepal_width',hue='species')

# %% [markdown]
# ![Task 8](images/task8.png)

# %%
data=px.data.gapminder()

# %%
data.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
sns.displot(data=data,x='gdpPercap',col='continent',col_wrap=2,kind='hist')

# %%
sns.relplot(data=data,kind='line',x='year',y='gdpPercap',col='continent',col_wrap=2)

# %%
plt.figure(figsize=(15,16))
sns.catplot(data=data,kind='violin',x='year',y='gdpPercap')
plt.show()

# %%
sns.displot(data=data,kind='kde',x='year')
plt.show()
