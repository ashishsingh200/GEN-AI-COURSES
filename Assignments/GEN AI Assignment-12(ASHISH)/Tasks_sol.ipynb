# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('possum.csv')

# %%
df.head(5)
# Out:
#    case  site  Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 0     1     1  Vic   m  8.0     94.1    60.4      89.0   36.0      74.5
# 1     2     1  Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
# 2     3     1  Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 3     4     1  Vic   f  6.0     93.2    57.1      92.0   38.0      76.1
# 4     5     1  Vic   f  2.0     91.5    56.3      85.5   36.0      71.0
#
#    earconch   eye  chest  belly
# 0      54.5  15.2   28.0   36.0
# 1      51.2  16.0   28.5   33.0
# 2      51.9  15.5   30.0   34.0
# 3      52.2  15.2   28.0   34.0
# 4      53.2  15.1   28.5   33.0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   case      104 non-null    int64
#  1   site      104 non-null    int64
#  2   Pop       104 non-null    str
#  3   sex       104 non-null    str
#  4   age       102 non-null    float64
#  5   hdlngth   104 non-null    float64
#  6   skullw    104 non-null    float64
#  7   totlngth  104 non-null    float64
#  8   taill     104 non-null    float64
#  9   footlgth  103 non-null    float64
#  10  earconch  104 non-null    float64
#  11  eye       104 non-null    float64
#  12  chest     104 non-null    float64
#  13  belly     104 non-null    float64
# dtypes: float64(10), int64(2), str(2)
# memory usage: 12.0 KB

# %%
# Returns True if all values in the column are unique, False if there are duplicates
print(df.nunique() == len(df))
# Out:
# case         True
# site        False
# Pop         False
# sex         False
# age         False
# hdlngth     False
# skullw      False
# totlngth    False
# taill       False
# footlgth    False
# earconch    False
# eye         False
# chest       False
# belly       False
# dtype: bool

# %% [markdown]
# ![Task 1](images/task1.png)

# %%
sns.relplot(data=df,y='age',x='totlngth',kind='line',hue='sex')
plt.show()

# %%
sns.relplot(data=df,y='age',x='totlngth',kind='scatter',hue='sex')
plt.show()

# %% [markdown]
# ![Task 2](images/task2.png)

# %%
sns.lineplot(data=df,x='taill',y='case',hue='sex')
# Out:
# <Axes: xlabel='taill', ylabel='case'>

# %%
sns.scatterplot(data=df,x='taill',y='case',hue='sex')
# Out:
# <Axes: xlabel='taill', ylabel='case'>

# %%
sns.relplot(data=df,x='chest',y='case',col='sex',col_wrap=2)

# %% [markdown]
# ![Task 3](images/task3.png)

# %%
df.head(5)
# Out:
#    case  site  Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 0     1     1  Vic   m  8.0     94.1    60.4      89.0   36.0      74.5
# 1     2     1  Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
# 2     3     1  Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 3     4     1  Vic   f  6.0     93.2    57.1      92.0   38.0      76.1
# 4     5     1  Vic   f  2.0     91.5    56.3      85.5   36.0      71.0
#
#    earconch   eye  chest  belly
# 0      54.5  15.2   28.0   36.0
# 1      51.2  16.0   28.5   33.0
# 2      51.9  15.5   30.0   34.0
# 3      52.2  15.2   28.0   34.0
# 4      53.2  15.1   28.5   33.0

# %%
df['Pop'].value_counts()
# Out:
# Pop
# other    58
# Vic      46
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (104, 14)

# %%
df['sex'].value_counts()
# Out:
# sex
# m    61
# f    43
# Name: count, dtype: int64

# %%
sns.histplot(data=df,x='belly',hue='sex',)
plt.show()

# %%
sns.kdeplot(data=df,x='age')
plt.show()

# %%
sns.histplot(data=df,x='age',hue='sex',kde=True)
plt.show()

# %%
sns.rugplot(data=df,x='Pop',y='age',hue='sex')
# Out:
# <Axes: xlabel='Pop', ylabel='age'>

# %% [markdown]
# ![Task 4](images/task4.png)

# %%
df.head()
# Out:
#    case  site  Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 0     1     1  Vic   m  8.0     94.1    60.4      89.0   36.0      74.5
# 1     2     1  Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
# 2     3     1  Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 3     4     1  Vic   f  6.0     93.2    57.1      92.0   38.0      76.1
# 4     5     1  Vic   f  2.0     91.5    56.3      85.5   36.0      71.0
#
#    earconch   eye  chest  belly
# 0      54.5  15.2   28.0   36.0
# 1      51.2  16.0   28.5   33.0
# 2      51.9  15.5   30.0   34.0
# 3      52.2  15.2   28.0   34.0
# 4      53.2  15.1   28.5   33.0

# %%
sns.histplot(data=df,x='skullw',y='footlgth',hue='Pop')
# Out:
# <Axes: xlabel='skullw', ylabel='footlgth'>

# %%
sns.kdeplot(data=df,x='eye',y='skullw',hue='Pop')
# Out:
# <Axes: xlabel='eye', ylabel='skullw'>

# %% [markdown]
# ![Task 5](images/task5.png)

# %%
df.head(5)
# Out:
#    case  site  Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 0     1     1  Vic   m  8.0     94.1    60.4      89.0   36.0      74.5
# 1     2     1  Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
# 2     3     1  Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 3     4     1  Vic   f  6.0     93.2    57.1      92.0   38.0      76.1
# 4     5     1  Vic   f  2.0     91.5    56.3      85.5   36.0      71.0
#
#    earconch   eye  chest  belly
# 0      54.5  15.2   28.0   36.0
# 1      51.2  16.0   28.5   33.0
# 2      51.9  15.5   30.0   34.0
# 3      52.2  15.2   28.0   34.0
# 4      53.2  15.1   28.5   33.0

# %%
pivot_data=df.pivot_table(columns='Pop',index='totlngth',values='eye')

# %%
sns.heatmap(pivot_data)
# Out:
# <Axes: xlabel='Pop', ylabel='totlngth'>

# %%
sns.pairplot(data=pivot_data)

# %% [markdown]
# ![Task 6](images/task6.png)

# %%
df.head(5)
# Out:
#    case  site  Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 0     1     1  Vic   m  8.0     94.1    60.4      89.0   36.0      74.5
# 1     2     1  Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
# 2     3     1  Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 3     4     1  Vic   f  6.0     93.2    57.1      92.0   38.0      76.1
# 4     5     1  Vic   f  2.0     91.5    56.3      85.5   36.0      71.0
#
#    earconch   eye  chest  belly
# 0      54.5  15.2   28.0   36.0
# 1      51.2  16.0   28.5   33.0
# 2      51.9  15.5   30.0   34.0
# 3      52.2  15.2   28.0   34.0
# 4      53.2  15.1   28.5   33.0

# %%
sns.barplot(data=df,x='Pop',y='chest')
# Out:
# <Axes: xlabel='Pop', ylabel='chest'>

# %%
sns.boxplot(data=df,x='Pop',y='totlngth')
# Out:
# <Axes: xlabel='Pop', ylabel='totlngth'>

# %%
sns.violinplot(data=df,x='Pop',y='totlngth')
# Out:
# <Axes: xlabel='Pop', ylabel='totlngth'>

# %%
sns.countplot(data=df,x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# ![Task 7](images/task7.png)

# %%
df.head(5)
# Out:
#    case  site  Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 0     1     1  Vic   m  8.0     94.1    60.4      89.0   36.0      74.5
# 1     2     1  Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
# 2     3     1  Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 3     4     1  Vic   f  6.0     93.2    57.1      92.0   38.0      76.1
# 4     5     1  Vic   f  2.0     91.5    56.3      85.5   36.0      71.0
#
#    earconch   eye  chest  belly
# 0      54.5  15.2   28.0   36.0
# 1      51.2  16.0   28.5   33.0
# 2      51.9  15.5   30.0   34.0
# 3      52.2  15.2   28.0   34.0
# 4      53.2  15.1   28.5   33.0

# %%
sns.regplot(data=df,x='skullw',y='eye')
# Out:
# <Axes: xlabel='skullw', ylabel='eye'>

# %%
sns.lmplot(data=df,x='skullw',y='eye',hue='sex')

# %% [markdown]
# ![Task 8](images/task8.png)

# %%
df.head()
# Out:
#    case  site  Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 0     1     1  Vic   m  8.0     94.1    60.4      89.0   36.0      74.5
# 1     2     1  Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
# 2     3     1  Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 3     4     1  Vic   f  6.0     93.2    57.1      92.0   38.0      76.1
# 4     5     1  Vic   f  2.0     91.5    56.3      85.5   36.0      71.0
#
#    earconch   eye  chest  belly
# 0      54.5  15.2   28.0   36.0
# 1      51.2  16.0   28.5   33.0
# 2      51.9  15.5   30.0   34.0
# 3      52.2  15.2   28.0   34.0
# 4      53.2  15.1   28.5   33.0

# %%
sns.displot(data=df,x='totlngth',col='sex',col_wrap=2,kind='hist')

# %%
sns.relplot(kind='line',data=df,x='totlngth',col='sex',y='eye',col_wrap=2)

# %%
#plt.figure(figsize=(15,16))
sns.catplot(data=df,kind='violin',x='eye',y='earconch')
plt.show()

# %%
sns.displot(data=df,kind='kde',x='eye')
plt.show()
